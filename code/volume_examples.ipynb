# %%
#Import Packages
print('Importing Packages')
import pandas as pd
import pickle
# Out:
# Importing Packages

# %%
volumes = pd.read_csv('../temporary/volumes_scores.csv')
volumes
# Out:
#         Religion   Science  Political Economy                      HTID  \
# 0       0.326938  0.164118           0.508944              uc1.b5568131
# 1       0.410077  0.104824           0.485099              uc1.$b135547
# 2       0.065574  0.629993           0.304434        hvd.32044106314859
# 3       0.400788  0.038419           0.560793               uc1.$b29323
# 4       0.028457  0.594895           0.376647        mdp.39015076816662
# ...          ...       ...                ...                       ...
# 158508  0.405057  0.192782           0.402161             chi.090018182
# 158509  0.270244  0.149941           0.579815        hvd.32044089522510
# 158510  0.161509  0.172480           0.666012        uc1.31175035187601
# 158511  0.134430  0.151041           0.714530  aeu.ark+=13960=t09w1n868
# 158512  0.031681  0.709332           0.258987  uc2.ark+=13960=t5x63cz39
#
#         industry_2  industry_3  percent_progress  percent_optimistic  \
# 0         0.099625    0.101499          0.000000            0.006072
# 1         0.151136    0.183048          0.003829            0.007906
# 2         0.000000    0.000000          0.000000            0.000216
# 3         0.051752    0.055923          0.000295            0.005821
# 4         0.044464    0.059229          0.007952            0.000374
# ...            ...         ...               ...                 ...
# 158508    0.367943    0.380383          0.004785            0.007571
# 158509    0.105344    0.125315          0.001843            0.005857
# 158510    0.183920    0.187089          0.004812            0.001592
# 158511    0.690849    0.736368          0.002845            0.001540
# 158512    0.042731    0.058919          0.004194            0.000162
#
#         percent_pessimism  percent_regression  ...  progress_regression  \
# 0                0.000486            0.000000  ...             0.000000
# 1                0.000405            0.000811  ...             0.003019
# 2                0.000000            0.000000  ...             0.000000
# 3                0.001574            0.000681  ...            -0.000386
# 4                0.000000            0.000287  ...             0.007665
# ...                   ...                 ...  ...                  ...
# 158508           0.000344            0.000918  ...             0.003867
# 158509           0.000910            0.000333  ...             0.001510
# 158510           0.000000            0.002341  ...             0.002471
# 158511           0.000000            0.000770  ...             0.002075
# 158512           0.000013            0.000364  ...             0.003830
#
#           Year  optimism_percentile  industry_2_percentile  \
# 0       1898.0             0.721099               0.329601
# 1       1832.0             0.934844               0.520582
# 2       1896.0             0.152196               0.006719
# 3       1825.0             0.564471               0.122097
# 4       1882.0             0.862207               0.096541
# ...        ...                  ...                    ...
# 158508  1843.0             0.944560               0.807820
# 158509  1874.0             0.782504               0.354406
# 158510  1808.0             0.584905               0.601320
# 158511  1857.0             0.538656               0.917464
# 158512  1883.0             0.576533               0.090775
#
#         industry_3_percentile  optimistic_percentile  progress_percentile  \
# 0                    0.292840               0.686776             0.175825
# 1                    0.564200               0.820841             0.904002
# 2                    0.006277               0.061055             0.175825
# 3                    0.114186               0.663737             0.437996
# 4                    0.124791               0.078788             0.980317
# ...                       ...                    ...                  ...
# 158508               0.797395               0.801089             0.935841
# 158509               0.390473               0.666895             0.762051
# 158510               0.573013               0.223225             0.936485
# 158511               0.917212               0.217241             0.851681
# 158512               0.123845               0.055819             0.917988
#
#         pessimism_percentile  regression_percentile  \
# 0                   0.376092               0.070177
# 1                   0.343808               0.600500
# 2                   0.089340               0.070177
# 3                   0.693287               0.515781
# 4                   0.089340               0.231735
# ...                      ...                    ...
# 158508              0.317646               0.661842
# 158509              0.523383               0.260382
# 158510              0.089340               0.947840
# 158511              0.089340               0.575609
# 158512              0.179052               0.281340
#
#         progress_regression_percentile
# 0                             0.521787
# 1                             0.905730
# 2                             0.521787
# 3                             0.340237
# 4                             0.984052
# ...                                ...
# 158508                        0.934926
# 158509                        0.807580
# 158510                        0.879316
# 158511                        0.854485
# 158512                        0.933778
#
# [158513 rows x 21 columns]

# %%
metapath = '../input/metadata.p'
metadata = pickle.load(open(metapath, 'rb'))

metadata['Year_rounded'] = pd.to_numeric(metadata['Year'])
metadata['Year'] = pd.to_numeric(metadata['Year'], downcast='signed')
def fix_htid(row):
    return row['HTID'].replace(":","+").replace("/", "=")

metadata['HTID'] = metadata.apply(fix_htid, axis=1)

# %%
h_progress = volumes[(volumes['Year'] >= 1700) & (volumes['Year'] <= 1850)]
h_progress = h_progress[(h_progress['progress_percentile'] >= 0.99) & (h_progress['industry_3_percentile'] >= 0.99)]
h_progress = h_progress.sort_values(by=['progress_percentile', 'industry_3_percentile'], ascending=False)
h_progress
# Out:
#         Religion   Science  Political Economy                 HTID  \
# 122671  0.088112  0.518323           0.393564   mdp.39015021046340
# 81270   0.132411  0.241612           0.625977   mdp.39015020921998
# 145533  0.123348  0.350349           0.526303   ien.35556037134509
# 35491   0.107997  0.416776           0.475226  umn.319510023761925
# 38798   0.205796  0.178978           0.615226   mdp.39015015421459
# 92727   0.185694  0.229197           0.585109   mdp.39015020112838
# 115315  0.108011  0.133041           0.758949       wu.89097040273
# 33502   0.083625  0.540437           0.375938   mdp.39015062316909
# 129692  0.086288  0.580182           0.333530   mdp.39015067103252
#
#         industry_2  industry_3  percent_progress  percent_optimistic  \
# 122671    5.783582    5.783582          0.037313            0.000000
# 81270     3.598773    3.863804          0.019632            0.001942
# 145533    2.607074    2.648597          0.019608            0.004620
# 35491     2.236979    2.268229          0.015625            0.000000
# 38798     1.941423    2.393305          0.014644            0.000000
# 92727     2.836663    2.836663          0.014101            0.002882
# 115315    1.937500    2.593750          0.011719            0.003200
# 33502     2.233314    2.255562          0.011409            0.001439
# 129692    2.618241    3.236156          0.011401            0.000000
#
#         percent_pessimism  percent_regression  ...  progress_regression  \
# 122671                0.0            0.000000  ...             0.037313
# 81270                 0.0            0.000000  ...             0.019632
# 145533                0.0            0.000000  ...             0.019608
# 35491                 0.0            0.006369  ...             0.009256
# 38798                 0.0            0.000000  ...             0.014644
# 92727                 0.0            0.000000  ...             0.014101
# 115315                0.0            0.000000  ...             0.011719
# 33502                 0.0            0.006235  ...             0.005174
# 129692                0.0            0.000000  ...             0.011401
#
#           Year  optimism_percentile  industry_2_percentile  \
# 122671  1840.0             0.999508               0.999981
# 81270   1848.0             0.995319               0.999407
# 145533  1830.0             0.997130               0.996909
# 35491   1822.0             0.904140               0.993401
# 38798   1836.0             0.978513               0.988594
# 92727   1850.0             0.988108               0.997874
# 115315  1831.0             0.979970               0.988487
# 33502   1840.0             0.791960               0.993357
# 129692  1837.0             0.949231               0.996959
#
#         industry_3_percentile  optimistic_percentile  progress_percentile  \
# 122671               0.999962               0.023459             0.999899
# 81270                0.999533               0.261240             0.998801
# 145533               0.996442               0.543463             0.998795
# 35491                0.992625               0.023459             0.997224
# 38798                0.994101               0.023459             0.996581
# 92727                0.997357               0.360497             0.996139
# 115315               0.995925               0.393668             0.993461
# 33502                0.992411               0.205683             0.992966
# 129692               0.998618               0.023459             0.992950
#
#         pessimism_percentile  regression_percentile  \
# 122671               0.08934               0.070177
# 81270                0.08934               0.070177
# 145533               0.08934               0.070177
# 35491                0.08934               0.996341
# 38798                0.08934               0.070177
# 92727                0.08934               0.070177
# 115315               0.08934               0.070177
# 33502                0.08934               0.996164
# 129692               0.08934               0.070177
#
#         progress_regression_percentile
# 122671                        0.999912
# 81270                         0.999041
# 145533                        0.999035
# 35491                         0.990209
# 38798                         0.997262
# 92727                         0.996921
# 115315                        0.994906
# 33502                         0.961606
# 129692                        0.994483
#
# [9 rows x 21 columns]

# %%
example_volumes = h_progress[['HTID', 'Year', 'industry_3_percentile', 'progress_percentile']]
example_volumes.to_csv('../output/example_volumes.csv', index=False)
