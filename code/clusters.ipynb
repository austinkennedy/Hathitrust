# %%
#Packages
import os
import pandas as pd

# %%
#Load Data
volume_weights = pd.read_csv("../temporary/topic_weights.csv")
cross = pd.read_csv('../temporary/cross_topics.csv')

# %%
# Out:
#                             HTID           1x2           1x3           1x4  \
# 0                   uc1.b5568131  2.358553e-04  1.294296e-05  2.361086e-02
# 1                   uc1.$b135547  4.531429e-06  8.976435e-08  3.039906e-06
# 2             hvd.32044106314859  5.547204e-10  2.649962e-10  4.257659e-10
# 3                    uc1.$b29323  4.502620e-11  5.553107e-08  1.894609e-07
# 4             mdp.39015076816662  1.044550e-11  2.258553e-09  8.017259e-12
# ...                          ...           ...           ...           ...
# 166774             chi.090018182  1.546693e-08  4.502479e-10  4.354511e-09
# 166775        hvd.32044089522510  4.891005e-06  2.572350e-03  1.556676e-07
# 166776        uc1.31175035187601  2.568527e-06  1.950825e-09  3.459992e-08
# 166777  aeu.ark+=13960=t09w1n868  5.597993e-07  4.021753e-09  6.461699e-09
# 166778  uc2.ark+=13960=t5x63cz39  2.125480e-12  1.015366e-12  1.631375e-12
#
# ...
